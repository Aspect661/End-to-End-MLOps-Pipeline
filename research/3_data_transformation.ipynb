# %%
import os

# %%
cd ~/MLOps/datascienceproject/
# Out:
# /Users/aspect/MLOps/datascienceproject

# %%
# %pwd
# Out:
# '/Users/aspect/MLOps/datascienceproject'

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass
class DataTransformationConfig:
    root_dir: Path
    data_path: Path

# %%
from src.datascience.constants import *
from src.datascience.utils.common import read_yaml, create_directories

# %%
class ConfiguartionManager:
    def __init__(
        self,
        config_filepath: Path = CONFIG_FILE_PATH,
        params_filepath: Path = PARAMS_FILE_PATH,
        schema_filepath: Path = SCHEMA_FILE_PATH
    ):
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        self.schema = read_yaml(schema_filepath)

    def get_data_transformation_config(self) -> DataTransformationConfig:

        config = self.config.data_transformation
        create_directories([config.root_dir])

        data_transformation_config = DataTransformationConfig(
            root_dir = config.root_dir,
            data_path = config.data_path
        )

        return data_transformation_config

# %%
import os
from src.datascience import logger
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
class DataTransformation:
    def __init__(self, config: DataTransformationConfig):
        self.config = config

    def train_test_splitting(self):

        data = pd.read_csv(self.config.data_path)

        # Splitting the data into train and test sets (0.75, 0.25)
        train, test = train_test_split(data, test_size=0.25, random_state=42)

        train.to_csv(os.path.join(self.config.root_dir, "train.csv"), index=False)
        test.to_csv(os.path.join(self.config.root_dir, "test.csv"), index=False)

        logger.info("Splitted data into training and test steps")
        logger.info(train.shape)
        logger.info(test.shape)

        print(train.shape)
        print(test.shape)

        print(train.shape)
        print(test.shape)

# %%
try:
    config = ConfiguartionManager()
    data_transformation_config = config.get_data_transformation_config()
    data_transformation = DataTransformation(config = data_transformation_config)
    data_transformation.train_test_splitting()

except Exception as e:
    raise e
# Out:
# [2026-06-13 13:16:01,814]: INFO: common: yaml file: config/config.yaml loaded successfully
# [2026-06-13 13:16:01,816]: INFO: common: yaml file: params.yaml loaded successfully
# [2026-06-13 13:16:01,817]: INFO: common: yaml file: schema.yaml loaded successfully
# [2026-06-13 13:16:01,818]: INFO: common: Created directory at artifacts/data_transformation
# [2026-06-13 13:16:01,868]: INFO: 4241828521: Splitted data into training and test steps
# [2026-06-13 13:16:01,869]: INFO: 4241828521: (1199, 12)
# [2026-06-13 13:16:01,869]: INFO: 4241828521: (400, 12)
# (1199, 12)
# (400, 12)
# (1199, 12)
# (400, 12)
